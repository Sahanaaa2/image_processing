# %%
#Program todisplay an grayscale image,number of rows and columns
import cv2
img = cv2.imread( "road.jpg",0)
if img is not None:
    #print("Image shape:", img.shape)
    #print("Image data type:", img.dtype)
    cv2.imshow("Image", img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
else:
    print("Failed to load image.")

# %%
rows,cols=img.shape

# %%
rows
# Out:
# 183

# %%
cols
# Out:
# 275

# %%
#Program to display a coloured image,rows,columns
import cv2
img = cv2.imread("road.jpg")
if img is not None:
    cv2.imshow("Image", img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    rows, cols, channels = img.shape
    print("Number of rows:", rows)
    print("Number of columns:", cols)
else:
    print("Failed to load image.")
# Out:
# Number of rows: 183
# Number of columns: 275

# %%
#Program to display original image,negative image
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('road.jpg')
plt.subplot(1,2,1)
plt.title("Original")
plt.imshow(image)

#gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.subplot(1,2,2)
plt.title("Grayscale")
plt.imshow(gray_image, cmap = 'gray')

# %%
#convert grayscale img to negetive using matplotlib
import cv2
import matplotlib.pyplot as plt
img=cv2.imread("road.jpg",0)
plt.subplot(1, 2, 1) 
plt.title("Original Image") 
plt.imshow(img)
rows,cols=img.shape
for i in range(rows):
    for j in range(cols):
        img[i,j]=255-img[i,j]
if img is not None:
    plt.subplot(1, 2, 2) 
    plt.title("Negetive image") 
    plt.imshow(img)
else:
    print("Failed to load the image")

# %%
#convert grayscale img to negetive using cvtcolor
import cv2
import matplotlib.pyplot as plt
img=cv2.imread("road.jpg")
grayscale = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.subplot(1, 2, 1)
plt.title("Original image")
plt.imshow(grayscale, cmap="gray")
rows,cols=grayscale.shape
for i in range(rows):
    for j in range(cols):
        grayscale[i,j]=255-grayscale[i,j]
if img is not None:
    plt.subplot(1, 2, 2) 
    plt.title("Negetive image") 
    plt.imshow(grayscale,cmap="gray")
else:
    print("Failed to load the image")

# %%
import cv2
import matplotlib.pyplot as plt
def negative_transformation(img, negative_value):
    grayscale = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    rows, cols = grayscale.shape
    for i in range(rows):
        for j in range(cols):
            grayscale[i, j] = negative_value - grayscale[i, j]
    return grayscale
def main():
    img = cv2.imread("road.jpg")
    if img is not None:
        while True:
            try:
                negative_value = int(input("Enter the negative transformation value (0-255): "))
                if 0 <= negative_value <= 255:
                    break
                else:
                    print("Invalid input. Please enter a value between 0 and 255.")
            except ValueError:
                print("Invalid input. Please enter a valid integer.")
        negative_image = negative_transformation(img, negative_value)
        plt.subplot(1, 2, 1)
        plt.title("Original image")
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for display

        plt.subplot(1, 2, 2)
        plt.title(f"Negative image (Value: {negative_value})")
        plt.imshow(negative_image, cmap="gray")

        plt.show()
    else:
        print("Failed to load the image")

if __name__ == "__main__":
    main()
# Out:
# Enter the negative transformation value (0-255): -1
# Invalid input. Please enter a value between 0 and 255.
# Enter the negative transformation value (0-255): 900
# Invalid input. Please enter a value between 0 and 255.
# Enter the negative transformation value (0-255): 56

# %%
import matplotlib.pyplot as plt
import cv2

def negate_image(gray_image, negation_value):
    rows, cols = gray_image.shape
    for i in range(rows):
        for j in range(cols):
            gray_image[i, j] = negation_value - gray_image[i, j]
    return gray_image

def main():
    img_path = "road.jpg"
    negation_value = int(input("Enter the negation value (0-255): "))
   
    img = cv2.imread(img_path)
    gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
   
    plt.subplot(1, 2, 1)
    plt.title("Original Image")
    plt.imshow(gray_image, cmap='gray')
   
    negated_image = negate_image(gray_image, negation_value)
   
    plt.subplot(1, 2, 2)
    plt.title('Negation Image')
    plt.imshow(negated_image, cmap='gray')
   
    plt.show()

main()
# Out:
# Enter the negation value (0-255): 300

# %%
import matplotlib.pyplot as plt
import cv2
img=cv2.imread('road.jpg')
gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.subplot(1,2,1)
plt.imshow(gray_img,cmap="gray")
plt.title("Original Image")
rows,cols=gray_img.shape
for i in range(rows):
    for j in range(cols):
        gray_img[i,j]=255-gray_img[i,j]
plt.subplot(1,2,2)
plt.imshow(gray_img,cmap="gray")
plt.title("Negation of Image")
# Out:
# Text(0.5, 1.0, 'Negation of Image')

# %%
import cv2
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

def negate_image(file_path):
    try:
        # For text files
        if file_path.endswith('.txt'):
            with open(file_path, 'r') as file:
                # Read the ASCII art from the text file
                ascii_art = file.read()

            # Convert ASCII art to image representation
            # This is a simplified example assuming each character represents a pixel
            # You may need to adjust this depending on the actual format of your text file
            image_data = []
            for line in ascii_art.split('\n'):
                row = []
                for char in line:
                    # Assuming char represents brightness, negate it
                    negated_brightness = 255 - ord(char)
                    row.append((negated_brightness, negated_brightness, negated_brightness))
                image_data.append(row)

            # Create a PIL Image object from the negated image data
            negated_image = Image.new('RGB', (len(image_data[0]), len(image_data)))
            for y, row in enumerate(image_data):
                for x, pixel in enumerate(row):
                    negated_image.putpixel((x, y), pixel)

        # For image files
        elif file_path.endswith(('.jpg', '.jpeg', '.png', '.bmp')):
            # Open the image using PIL
            image = Image.open(file_path)

            # Convert image to grayscale and negate it
            negated_image = Image.eval(image, lambda x: 255 - x)

        # For video files
        elif file_path.endswith(('.mp4', '.avi', '.mov')):
            # Open video file using OpenCV
            cap = cv2.VideoCapture(file_path)

            # Read the first frame
            ret, frame = cap.read()

            # Convert frame to grayscale and negate it
            negated_frame = cv2.bitwise_not(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY))

            # Convert numpy array to PIL Image
            negated_image = Image.fromarray(negated_frame)

            # Release the video capture object
            cap.release()

        else:
            print("Unsupported file type.")
            return

        # Convert PIL Image to NumPy array
        negated_array = np.array(negated_image)

        # Plot the negated image
        plt.imshow(negated_array)
        plt.axis('off')
        plt.show()

    except FileNotFoundError:
        print("File not found. Please enter a valid file path.")


# Allow the user to input the file path dynamically
file_path = input("Enter the path to the file: ")
negate_image(file_path)
