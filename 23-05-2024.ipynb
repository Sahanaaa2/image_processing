# %%
#Python program to find mean and variance of 20 images
import os
import cv2
import matplotlib.pyplot as plt

def find_mean_variance(img):
    rows, cols = img.shape
    
    sum1 = 0

    for i in range(rows):
        for j in range(cols):
            sum1 += img[i,j]
    mean = sum1 / (rows * cols)
    
    varianceSum = 0
    
    for i in range(rows):
        for j in range(cols):
            varianceSum += (img[i,j] - mean) ** 2
    variance = varianceSum / (rows * cols)
    
    return mean, variance 
    
root_folder = "C:\\Users\\User\\image_processing//images"
imgList = []
for file in os.listdir(root_folder): 
    if file.endswith(('.jpg', '.jpeg', '.png', '.gif','.jfif')):
        file_path = os.path.join(root_folder,file)
        imgList.append(file_path)

means = []
variances = []

for i in range(len(imgList)):
    print(imgList[i])
    imgOb = cv2.imread(imgList[i]) 
    
    gray_image = cv2.cvtColor(imgOb, cv2.COLOR_BGR2GRAY) 
    mean, variance = find_mean_variance(gray_image)
    
    means.append(mean)
    variances.append(variance)

print("Means: ", means)
print("Variances : ", variances)
plt.scatter(means,variances)
# Out:
# C:\Users\User\image_processing//images\bird.jpg
# C:\Users\User\image_processing//images\bird1.jpg
# C:\Users\User\image_processing//images\cat.jpg
# C:\Users\User\image_processing//images\cats.jpg
# C:\Users\User\image_processing//images\drop.jpg
# C:\Users\User\image_processing//images\droplets.jpg
# C:\Users\User\image_processing//images\elephant.jpg
# C:\Users\User\image_processing//images\flower.jpg
# C:\Users\User\image_processing//images\forest.jpg
# C:\Users\User\image_processing//images\green.jpg
# C:\Users\User\image_processing//images\icecream.jpg
# C:\Users\User\image_processing//images\lion.jpg
# C:\Users\User\image_processing//images\nature.jpeg
# C:\Users\User\image_processing//images\pink.jpg
# C:\Users\User\image_processing//images\road.jpg
# C:\Users\User\image_processing//images\rose.jpg
# C:\Users\User\image_processing//images\skys.jpg
# C:\Users\User\image_processing//images\spring.jpg
# C:\Users\User\image_processing//images\sunsets.jpg
# C:\Users\User\image_processing//images\white.jpg
# Means:  [124.74039150155168, 110.02511225215613, 146.35485345255836, 190.49213012597158, 90.69859504132232, 156.74228467039802, 114.51965, 66.8467958271237, 47.29100833333333, 76.7439768735363, 194.95875, 122.69788027656477, 92.28513937114198, 180.69307248263888, 86.30277198211624, 37.753224043715846, 96.79721808246398, 85.2839514112183, 141.05688833477447, 61.98448148148148]
# Variances :  [3354.91414237875, 1327.0448703968057, 1281.6757283068666, 6886.498370124784, 3156.612130257498, 2884.7165468944827, 4542.542447210876, 1093.4438707567158, 1378.5897558167123, 3907.9940101214584, 4777.731497610709, 1373.3387909944179, 3509.4102720240717, 2783.0876145101665, 2341.476714620944, 868.496935705864, 5227.178213820369, 1815.5321261512015, 3150.5759562742683, 3410.190936953208]

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\User\\image_processing'

# %%
#Python program to implement arithematic operations on two images
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load images
image1 = cv2.imread('C:\\Users\\User\\image_processing\\images\\bird.jpg')
image2 = cv2.imread('C:\\Users\\User\\image_processing\\images\\drop.jpg')
rows, cols = image2.shape[:2]

# Ensure the images are of the same size
image1 = cv2.resize(image1, (cols,rows))

added_image = cv2.add(image1, image2)
sub_image = cv2.subtract(image2, image1)
multiplied_image = cv2.multiply(image1, image2)

image1_float = image1.astype(np.float32)
image2_float = image2.astype(np.float32) + 1  # Adding 1 to avoid division by zero

divided_image = cv2.divide(image1_float, image2_float)

# Convert back to uint8
divided_image = cv2.normalize(divided_image, None, 0, 255, cv2.NORM_MINMAX)
divided_image = divided_image.astype(np.uint8)

plt.figure(figsize = (8,12))
plt.subplot(3,2,1)
plt.imshow(cv2.cvtColor(image1, cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(3,2,2)
plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(3,2,3)
plt.imshow(cv2.cvtColor(added_image, cv2.COLOR_BGR2RGB))
plt.title('Added Image')

plt.subplot(3,2,4)
plt.imshow(cv2.cvtColor(sub_image, cv2.COLOR_BGR2RGB))
plt.title('Subtracted Image')

plt.subplot(3,2,5)
plt.imshow(cv2.cvtColor(multiplied_image, cv2.COLOR_BGR2RGB))
plt.title('Multiplied Image')

plt.subplot(3,2,6)
plt.imshow(cv2.cvtColor(divided_image, cv2.COLOR_BGR2RGB))
plt.title('Divided Image')
# Out:
# Text(0.5, 1.0, 'Divided Image')

# %%
#Python program to implement bitwise operations on two images
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load two images
img1 = cv2.imread('C:\\Users\\User\\image_processing\\images\\road.jpg')
img2 = cv2.imread('C:\\Users\\User\\image_processing\\images\\spring.jpg')

# Resize images to the same dimensions if needed
img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

# Perform bitwise AND operation
bitwise_and = cv2.bitwise_and(img1, img2)

# Perform bitwise OR operation
bitwise_or = cv2.bitwise_or(img1, img2)

# Perform bitwise XOR operation
bitwise_xor = cv2.bitwise_xor(img1, img2)

# Perform bitwise NOT operation
bitwise_not_img1 = cv2.bitwise_not(img1)
bitwise_not_img2 = cv2.bitwise_not(img2)

# Display results
plt.figure(figsize = (8,12))
plt.subplot(4,2,1)
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(4,2,2)
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(4,2,3)
plt.imshow(cv2.cvtColor(bitwise_and, cv2.COLOR_BGR2RGB))
plt.title('Bitwise AND Image')

plt.subplot(4,2,4)
plt.imshow(cv2.cvtColor(bitwise_or, cv2.COLOR_BGR2RGB))
plt.title('Bitwise OR Image')

plt.subplot(4,2,5)
plt.imshow(cv2.cvtColor(bitwise_not_img1, cv2.COLOR_BGR2RGB))
plt.title('Bitwise NOT Image 1')

plt.subplot(4,2,6)
plt.imshow(cv2.cvtColor(bitwise_not_img2, cv2.COLOR_BGR2RGB))
plt.title('Bitwise NOT Image 2')

plt.subplot(4,2,7)
plt.imshow(cv2.cvtColor(bitwise_xor, cv2.COLOR_BGR2RGB))
plt.title('Bitwise XOR Image')
# Out:
# Text(0.5, 1.0, 'Bitwise XOR')

# %%
#Python program to implement logical operations on two images
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Function to threshold image to binary per channel
def threshold_image(image, threshold=128):
    # Split the image into its color channels
    channels = cv2.split(image)
    binary_channels = []
    for channel in channels:
        _, binary_channel = cv2.threshold(channel, threshold, 255, cv2.THRESH_BINARY)
        binary_channels.append(binary_channel)
    return cv2.merge(binary_channels)

# Load images
image1 = cv2.imread('C:\\Users\\User\\image_processing\\images\\icecream.jpg')
image2 = cv2.imread('C:\\Users\\User\\image_processing\\images\\nature.jpeg')

# Ensure the images are of the same size
image1 = cv2.resize(image1, (image2.shape[1], image2.shape[0]))

# Threshold images to create binary images
binary_image1 = threshold_image(image1)
binary_image2 = threshold_image(image2)

# Perform logical AND operation
logical_and = np.logical_and(binary_image1, binary_image2).astype(np.uint8) * 255

# Perform logical OR operation
logical_or = np.logical_or(binary_image1, binary_image2).astype(np.uint8) * 255

# Perform logical NOT operation on the first image
logical_not = np.logical_not(binary_image1).astype(np.uint8) * 255

# Display the results
plt.figure(figsize=(12, 10))

plt.subplot(2, 2, 1)
plt.imshow(cv2.cvtColor(image1, cv2.COLOR_BGR2RGB))
plt.title('Original Image 1')

plt.subplot(2, 2, 2)
plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))
plt.title('Original Image 2')

plt.subplot(2, 2, 3)
plt.imshow(cv2.cvtColor(logical_and, cv2.COLOR_BGR2RGB))
plt.title('Logical AND Image')

plt.subplot(2, 2, 4)
plt.imshow(cv2.cvtColor(logical_or, cv2.COLOR_BGR2RGB))
plt.title('Logical OR Image')

plt.figure()
plt.imshow(cv2.cvtColor(logical_not, cv2.COLOR_BGR2RGB))
plt.title('Logical NOT Image')
plt.show()

# %%
#Python program to perform arithematic operations(addition) on two images
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Function to add two images manually
def add_images(image1, image2):
    # Ensure the images have the same dimensions
    if image1.shape != image2.shape:
        raise ValueError("Images must have the same dimensions for addition.")
   
    # Convert images to int32 to handle overflow
    image1_int = image1.astype(np.int32)
    image2_int = image2.astype(np.int32)
   
    # Create an empty array for the output image
    result_image = np.zeros_like(image1_int)
   
    rows, cols, channels = image1_int.shape
   
    # Manually add pixel values
    for row in range(rows):
        for col in range(cols):
            for channel in range(channels):
                pixel_sum = image1_int[row, col, channel] + image2_int[row, col, channel]
                result_image[row, col, channel] = np.clip(pixel_sum, 0, 255)
   
    # Convert back to uint8
    result_image = result_image.astype(np.uint8)
   
    return result_image

# Load images
image1 = cv2.imread('C:\\Users\\User\\image_processing\\images\\green.jpg')
image2 = cv2.imread('C:\\Users\\User\\image_processing\\images\\pink.jpg')

# Ensure the images are of the same size
image1 = cv2.resize(image1, (image2.shape[1], image2.shape[0]))

# Add images manually
added_image = add_images(image1, image2)

# Display the result
plt.figure(figsize=(12, 8))

plt.subplot(1, 3, 1)
plt.imshow(cv2.cvtColor(image1, cv2.COLOR_BGR2RGB))
plt.title('Original Image 1')

plt.subplot(1, 3, 2)
plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))
plt.title('Original Image 2')

plt.subplot(1, 3, 3)
plt.imshow(cv2.cvtColor(added_image, cv2.COLOR_BGR2RGB))
plt.title('Added Image')
# Out:
# Text(0.5, 1.0, 'Added Image')
